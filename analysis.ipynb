# %%
import numpy as np
import pandas as pd
from modules.voters_functions import votes_from_one_group

# %% [markdown]
# Probability to vote for candidate equals the probability of voting for Ventura.

# %% [markdown]
# Default profiles in Portugal

# %%
portugal_all_voters = 9262653
portugal_valid_votes = 5696638
portugal_blank_votes = 60899
portugal_null_votes = 64817
portugal_abstentionists = portugal_all_voters - (portugal_valid_votes + portugal_blank_votes + portugal_null_votes)
portugal_turnout_eleitor_activo = 0.98
eleitor_portugal_seguro = {
    "first_turn_votes": 1738741,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_portugal_ventura = {
    "first_turn_votes": 1297533,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 1,
}
eleitor_portugal_figueiredo = {
    "first_turn_votes": 891788,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_portugal_gouveia_melo = {
    "first_turn_votes": 691489,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_portugal_marques_mendes = {
    "first_turn_votes": 631809,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_portugal_martins = {
    "first_turn_votes": 114468,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_portugal_filipe = {
    "first_turn_votes": 91889,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_portugal_vieira = {
    "first_turn_votes": 60266,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_portugal_pinto = {
    "first_turn_votes": 37671,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_portugal_silva = {
    "first_turn_votes": 10674,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_portugal_correia = {
    "first_turn_votes": 4594,
    "probability_to_turnout": portugal_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_portugal_abstencionista = {
    "first_turn_votes": portugal_abstentionists,
    "probability_to_turnout": 0.25,
    "probability_to_vote_for_candidate": 0.5,
}

# %% [markdown]
# Default profiles in out of Portugal

# %%
abroad_all_voters = 1754549
abroad_valid_votes = 70419
abroad_blank_votes = 327
abroad_null_votes = 564
abroad_abstentionists = abroad_all_voters - (abroad_valid_votes + abroad_blank_votes + abroad_null_votes)
abroad_turnout_eleitor_activo = 0.5

eleitor_abroad_ventura = {
    "first_turn_votes": 29115,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 1,
}
eleitor_abroad_seguro = {
    "first_turn_votes": 16163,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_abroad_figueiredo = {
    "first_turn_votes": 10783,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_abroad_gouveia_melo = {
    "first_turn_votes": 3602,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_abroad_marques_mendes = {
    "first_turn_votes": 5585,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_abroad_martins = {
    "first_turn_votes": 1835,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_abroad_filipe = {
    "first_turn_votes": 700,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_abroad_vieira = {
    "first_turn_votes": 633,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_abroad_pinto = {
    "first_turn_votes": 865,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_abroad_silva = {
    "first_turn_votes": 219,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0,
}
eleitor_abroad_correia = {
    "first_turn_votes": 28,
    "probability_to_turnout": abroad_turnout_eleitor_activo,
    "probability_to_vote_for_candidate": 0.5,
}
eleitor_abroad_abstencionista = {
    "first_turn_votes": abroad_abstentionists,
    "probability_to_turnout": 0.25,
    "probability_to_vote_for_candidate": 0.5,
}

# %%
voters_groups = [
    eleitor_portugal_seguro,
    eleitor_portugal_ventura,
    eleitor_portugal_figueiredo,
    eleitor_portugal_gouveia_melo,
    eleitor_portugal_marques_mendes,
    eleitor_portugal_martins,
    eleitor_portugal_filipe,
    eleitor_portugal_vieira,
    eleitor_portugal_pinto,
    eleitor_portugal_silva,
    eleitor_portugal_correia,
    eleitor_portugal_abstencionista,
    eleitor_abroad_ventura,
    eleitor_abroad_seguro,
    eleitor_abroad_figueiredo,
    eleitor_abroad_gouveia_melo,
    eleitor_abroad_marques_mendes,
    eleitor_abroad_martins,
    eleitor_abroad_filipe,
    eleitor_abroad_vieira,
    eleitor_abroad_pinto,
    eleitor_abroad_silva,
    eleitor_abroad_correia,
    eleitor_abroad_abstencionista,
]

# %%
def simulate_second_round(voter_groups, n_simulations=10000):
    results = []
    for _ in range(n_simulations):
        total_votes_candidate_1 = 0
        total_votes_candidate_2 = 0
        for group in voter_groups:
            votes = votes_from_one_group(
                group["first_turn_votes"],
                group["probability_to_turnout"],
                group["probability_to_vote_for_candidate"]
            )
            total_votes_candidate_1 += votes
            total_votes_candidate_2 += group["first_turn_votes"] * group["probability_to_turnout"] - votes
        results.append((total_votes_candidate_1, total_votes_candidate_2))
    return results
